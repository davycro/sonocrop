# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

# %%
sys.path.insert(0, os.path.abspath('../'))
sys.path
# Out:
# ['/Users/david/ai/sonocrop/pypi',
#  '/Users/david/ai/sonocrop/pypi/nbs',
#  '/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python37.zip',
#  '/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7',
#  '/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/lib-dynload',
#  '',
#  '/Users/david/Library/Python/3.7/lib/python/site-packages',
#  '/usr/local/lib/python3.7/site-packages',
#  '/usr/local/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/david/.ipython']

# %%
from sonocrop import plot

# %%
# Set media path and list directory contents
mediaPath = Path('autocrop_media')
display(os.listdir(str(mediaPath)))

vidFile = mediaPath/'low-frame-count.mov'
# Out:
# ['echo-with-borders.mp4',
#  'heavy-borders.mp4',
#  'simple-soft-tissue.mp4',
#  'lung.mov',
#  'odd-window-size.mov',
#  'dynamic-sample.avi',
#  'low-frame-count.mov',
#  'ruq-simple.mp4']

# %%
plot.showVideoProperties(vidFile)
# Out:
# Video file: autocrop_media/low-frame-count.mov
# Frame count: 20, fps: 11, width x height: 800x600
# True

# %%
plot.showFrame(vidFile, frame_number=10)

# %%
plot.plotPixel(vidFile, 40, 40, frame_number=10)

# %%
plot.plotColorVariation3D(vidFile)

# %%
plot.plotEdgeDetection(vidFile)

# %%
plot.showEdges(vidFile)
